# %%
import re
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# !rsync -av conrad.navydsrc.hpc.mil:ForcedChannel/results/ChannelCoarse02/input/STDOUT.0000 ../reduceddata/STDOUT.0000
fig, ax = plt.subplots(2, 2, constrained_layout=True, sharex=True)
for fn in ['../reduceddata/IWNoLeith/STDOUT.0000', '../reduceddata/IWAllLeith/STDOUT.0000', ]:
    time = np.zeros(20000)
    meantemp = np.zeros(20000)
    meanu = np.zeros(20000)
    meanke = np.zeros(20000)
    cflw = np.zeros(20000)
    n=-1
    with open(fn, 'r') as fin:
        for line in fin:
            if 'time_secondsf' in line:
                n += 1
                time[n] = float(line.split('=')[1])
            elif 'ke_mean' in line:
                meanke[n] = float(line.split('=')[1])
            elif 'dynstat_uvel_mean' in line:
                meanu[n] = float(line.split('=')[1])
            elif 'dynstat_theta_mean' in line:
                meantemp[n] = float(line.split('=')[1])
            elif 'advcfl_wvel_max' in line:
                cflw[n] = float(line.split('=')[1])
    time = time[:n]/3600/12.4
    meantemp = meantemp[:n]
    meanke = meanke[:n]
    cflw = cflw[:n]
    meanu = meanu[:n]
    ax[0,0].plot(time, meanke)
    ax[0,1].plot(time, meantemp)
    ax[1,0].plot(time, cflw)
    ax[1,1].plot(time, meanu)
ax[0,0].set_title(time[-1])
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'16.854444444444447')

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('%010d'%(3.390120000000E+09/3600))
print('%d'%(3.390120000000E+09))
3390120000/3600/24/365
# Out:
# 0000941700
# 3390120000
# 107.5

# %%
100*365*24*3600*2
# Out:
# 6307200000
